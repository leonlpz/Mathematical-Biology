# %% [markdown]
# # Romeo and Juliet love affair
# ## Linear dynamicsl system
#
# jkfjwrht wfwqñrghñrwjgwñerj wñrhgrgh

# %%
from pylab import *
from scipy.integrate import odeint
# %matplotlib inline

# %%
3 * 5
# Out:
# 15

# %%
sin(2 * pi) + 1
# Out:
# 0.99999999999999978

# %%
a = cos(pi / 2) - 3

# %%
a
# Out:
# -3.0

# %%
x = linspace(-pi, pi, 300)

# %%
len(x)
# Out:
# 300

# %%
plot(x, sin(x))
xlabel(r'$x$')
ylabel(r'$\sin(x)$')
title(r'Plot of $\sin(x)$')

# %%
def loveAffair(x, t):
    R = x[0]
    J = x[1]
    dR = a * R + J
    dJ = - R
    dx = array([dR, dJ])
    return dx

# %%
a = -1
la = loveAffair([-1, -1], 0)

# %%
la
# Out:
# array([0, 1])

# %%
la[0]
# Out:
# 0

# %%
la[1]
# Out:
# 1

# %%
t = linspace(0, 100, 2000)
a = -3

# %%
x = odeint(loveAffair, [5, 5], t)

# %%
x
# Out:
# array([[  5.00000000e+00,   5.00000000e+00],
#        [  4.52971823e+00,   4.76188238e+00],
#        [  4.11444939e+00,   4.54588476e+00],
#        ...,
#        [  1.47049952e-10,   3.86384395e-10],
#        [  1.55724880e-10,   4.09252143e-10],
#        [  1.64401471e-10,   4.32124652e-10]])

# %%
x[1,0]
# Out:
# 4.5297182322175722

# %%
x[1, :]
# Out:
# array([ 4.52971823,  4.76188238])

# %%
x[:, 0]
# Out:
# array([  5.00000000e+00,   4.52971823e+00,   4.11444939e+00, ...,
#          1.47049952e-10,   1.55724880e-10,   1.64401471e-10])

# %%
plot(t, x[:,0])
plot(t, x[:,1])

# %%
x = odeint(loveAffair, [5, 5], t)
plot(x[:,0], x[:, 1], color = 'blue')
x = odeint(loveAffair, [3, 5], t)
plot(x[:,0], x[:, 1], color = 'blue')
x = odeint(loveAffair, [-5, 5], t)
plot(x[:,0], x[:, 1], color = 'blue')
x = odeint(loveAffair, [-5, 2], t)
plot(x[:,0], x[:, 1], color = 'blue')
x = odeint(loveAffair, [-5, -2], t)
plot(x[:,0], x[:, 1], color = 'blue')
x = odeint(loveAffair, [5, -5], t)
plot(x[:,0], x[:, 1], color = 'blue')
x = odeint(loveAffair, [5, -2], t)
plot(x[:,0], x[:, 1], color = 'blue')
x = odeint(loveAffair, [5, 2], t)
plot(x[:,0], x[:, 1], color = 'blue')
x = odeint(loveAffair, [-5, -5], t)
plot(x[:,0], x[:, 1], color = 'blue')

# %%
a = -1
x = odeint(loveAffair, [5, 5], t)
plot(x[:,0], x[:, 1], color = 'blue')
x = odeint(loveAffair, [3, 5], t)
plot(x[:,0], x[:, 1], color = 'blue')
x = odeint(loveAffair, [-5, 5], t)
plot(x[:,0], x[:, 1], color = 'blue')
x = odeint(loveAffair, [-5, 2], t)
plot(x[:,0], x[:, 1], color = 'blue')
x = odeint(loveAffair, [-5, -2], t)
plot(x[:,0], x[:, 1], color = 'blue')
x = odeint(loveAffair, [5, -5], t)
plot(x[:,0], x[:, 1], color = 'blue')
x = odeint(loveAffair, [5, -2], t)
plot(x[:,0], x[:, 1], color = 'blue')
x = odeint(loveAffair, [5, 2], t)
plot(x[:,0], x[:, 1], color = 'blue')
x = odeint(loveAffair, [-5, -5], t)
plot(x[:,0], x[:, 1], color = 'blue')

# %%
a = 0
x = odeint(loveAffair, [5, 5], t)
plot(x[:,0], x[:, 1], color = 'blue')
x = odeint(loveAffair, [3, 5], t)
plot(x[:,0], x[:, 1], color = 'blue')
x = odeint(loveAffair, [-5, 5], t)
plot(x[:,0], x[:, 1], color = 'blue')
x = odeint(loveAffair, [-5, 2], t)
plot(x[:,0], x[:, 1], color = 'blue')
x = odeint(loveAffair, [-5, -2], t)
plot(x[:,0], x[:, 1], color = 'blue')
x = odeint(loveAffair, [5, -5], t)
plot(x[:,0], x[:, 1], color = 'blue')
x = odeint(loveAffair, [5, -2], t)
plot(x[:,0], x[:, 1], color = 'blue')
x = odeint(loveAffair, [5, 2], t)
plot(x[:,0], x[:, 1], color = 'blue')
x = odeint(loveAffair, [-5, -5], t)
plot(x[:,0], x[:, 1], color = 'blue')

# %%
a = 1
x = odeint(loveAffair, [5, 5], t)
plot(x[:,0], x[:, 1], color = 'blue')
x = odeint(loveAffair, [3, 5], t)
plot(x[:,0], x[:, 1], color = 'blue')
x = odeint(loveAffair, [-5, 5], t)
plot(x[:,0], x[:, 1], color = 'blue')
x = odeint(loveAffair, [-5, 2], t)
plot(x[:,0], x[:, 1], color = 'blue')
x = odeint(loveAffair, [-5, -2], t)
plot(x[:,0], x[:, 1], color = 'blue')
x = odeint(loveAffair, [5, -5], t)
plot(x[:,0], x[:, 1], color = 'blue')
x = odeint(loveAffair, [5, -2], t)
plot(x[:,0], x[:, 1], color = 'blue')
x = odeint(loveAffair, [5, 2], t)
plot(x[:,0], x[:, 1], color = 'blue')
x = odeint(loveAffair, [-5, -5], t)
plot(x[:,0], x[:, 1], color = 'blue')

# %%
a = 3
x = odeint(loveAffair, [5, 5], t)
plot(x[:,0], x[:, 1], color = 'blue')
x = odeint(loveAffair, [3, 5], t)
plot(x[:,0], x[:, 1], color = 'blue')
x = odeint(loveAffair, [-5, 5], t)
plot(x[:,0], x[:, 1], color = 'blue')
x = odeint(loveAffair, [-5, 2], t)
plot(x[:,0], x[:, 1], color = 'blue')
x = odeint(loveAffair, [-5, -2], t)
plot(x[:,0], x[:, 1], color = 'blue')
x = odeint(loveAffair, [5, -5], t)
plot(x[:,0], x[:, 1], color = 'blue')
x = odeint(loveAffair, [5, -2], t)
plot(x[:,0], x[:, 1], color = 'blue')
x = odeint(loveAffair, [5, 2], t)
plot(x[:,0], x[:, 1], color = 'blue')
x = odeint(loveAffair, [-5, -5], t)
plot(x[:,0], x[:, 1], color = 'blue')
